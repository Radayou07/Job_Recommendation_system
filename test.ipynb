# %%
import torch

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cpu
# /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages/torch/cuda/__init__.py:187: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 12040). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at /pytorch/c10/cuda/CUDAFunctions.cpp:119.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
# %pip uninstall torch torchvision torchaudio -y
# Out:
# Found existing installation: torch 2.12.0
# Uninstalling torch-2.12.0:
#   Successfully uninstalled torch-2.12.0
# WARNING: Failed to remove contents in a temporary directory '/media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages/~orch'.
# You can safely remove it manually.
# WARNING: Skipping torchvision as it is not installed.
# WARNING: Skipping torchaudio as it is not installed.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# Collecting torch==2.6.0
#   Downloading https://download-r2.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp313-cp313-linux_x86_64.whl.metadata (28 kB)
# Collecting torchvision==0.21.0
#   Downloading https://download-r2.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp313-cp313-linux_x86_64.whl.metadata (6.1 kB)
# Collecting torchaudio==2.6.0
#   Downloading https://download-r2.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp313-cp313-linux_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: filelock in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from torch==2.6.0) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from torch==2.6.0) (4.15.0)
# Requirement already satisfied: networkx in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from torch==2.6.0) (3.6.1)
# Requirement already satisfied: jinja2 in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from torch==2.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from torch==2.6.0) (2026.4.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 1.3 MB/s eta 0:00:0000:0100:01m
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 1.1 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 916.7 kB/s eta 0:00:0000:0100:19
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 903.8 kB/s eta 0:00:0000:0100:11
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 812.4 kB/s eta 0:00:0000:0100:09
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 1.3 MB/s eta 0:00:0000:0100:02
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 1.4 MB/s eta 0:00:0000:0100:03
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.3 MB/s eta 0:00:0000:0100:05
# Collecting nvidia-cusparselt-cu12==0.6.2 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting nvidia-nccl-cu12==2.21.5 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/nvidia_nccl_cu12-2.21.5-py3-none-manylinux2014_x86_64.whl (188.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 1.3 MB/s eta 0:00:0000:0100:05
# Collecting nvidia-nvtx-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvtx_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (99 kB)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch==2.6.0)
#   Downloading https://download.pytorch.org/whl/cu124/nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 1.3 MB/s eta 0:00:0000:0100:01
# Collecting triton==3.2.0 (from torch==2.6.0)
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='download-r2.pytorch.org', port=443): Read timed out. (read timeout=15)")': /whl/triton-3.2.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata
#   Downloading https://download-r2.pytorch.org/whl/triton-3.2.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: setuptools in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from torch==2.6.0) (81.0.0)
# Collecting sympy==1.13.1 (from torch==2.6.0)
#   Downloading sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from torchvision==0.21.0) (2.4.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from torchvision==0.21.0) (12.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from sympy==1.13.1->torch==2.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /media/radayou/DATA/Study/ITC/Year 3/2nd semester/Mini Project/.venv/lib/python3.13/site-packages (from jinja2->torch==2.6.0) (3.0.3)
# Downloading https://download-r2.pytorch.org/whl/cu124/torch-2.6.0%2Bcu124-cp313-cp313-linux_x86_64.whl (768.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 768.4/768.4 MB 1.1 MB/s eta 0:00:0000:0100:18m
# Downloading https://download-r2.pytorch.org/whl/cu124/torchvision-0.21.0%2Bcu124-cp313-cp313-linux_x86_64.whl (7.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 974.6 kB/s eta 0:00:00a 0:00:01
# Downloading https://download-r2.pytorch.org/whl/cu124/torchaudio-2.6.0%2Bcu124-cp313-cp313-linux_x86_64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 959.0 kB/s eta 0:00:00a 0:00:01
# Downloading https://download.pytorch.org/whl/cu124/nvidia_cusparselt_cu12-0.6.2-py3-none-manylinux2014_x86_64.whl (150.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.1/150.1 MB 1.1 MB/s eta 0:00:0000:0100:04m
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='files.pythonhosted.org', port=443): Read timed out. (read timeout=15)")': /packages/b2/fe/81695a1aa331a842b582453b605175f419fe8540355886031328089d840a/sympy-1.13.1-py3-none-any.whl
# Downloading sympy-1.13.1-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 1.2 MB/s eta 0:00:00a 0:00:01
# Downloading https://download-r2.pytorch.org/whl/triton-3.2.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (166.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.7/166.7 MB 1.1 MB/s eta 0:00:0000:0100:04
# Installing collected packages: triton, nvidia-cusparselt-cu12, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, torchaudio
#   Attempting uninstall: triton
#     Found existing installation: triton 3.7.0
#     Uninstalling triton-3.7.0:
#       Successfully uninstalled triton-3.7.0
#   Attempting uninstall: sympy━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/18 [nvidia-cusparselt-cu12]
#     Found existing installation: sympy 1.14.0━━━━━━━━━━━━━━━━━  1/18 [nvidia-cusparselt-cu12]
#     Uninstalling sympy-1.14.0:m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  2/18 [sympy]parselt-cu12]
#       Successfully uninstalled sympy-1.14.0━━━━━━━━━━━━━━━━━━━━━━━  2/18 [sympy]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18/18 [torchaudio]8 [torchaudio]]ver-cu12]2]2]
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-cusparselt-cu12-0.6.2 nvidia-nccl-cu12-2.21.5 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.4.127 sympy-1.13.1 torch-2.6.0+cu124 torchaudio-2.6.0+cu124 torchvision-0.21.0+cu124 triton-3.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# %docker run --gpus all -it nvcr.io/nvidia/tensorflow:24.04-tf2-py3

# %%
import torch

print(f"PyTorch: {torch.__version__}")
print(f"CUDA Build: {torch.version.cuda}")
print(f"Available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"Compute Capability: {torch.cuda.get_device_capability(0)}")
else:
    print("GPU NOT detected. Check driver installation.")
# Out:
# PyTorch: 2.6.0+cu124
# CUDA Build: 12.4
# Available: True
# GPU: NVIDIA GeForce RTX 4060 Laptop GPU
# Compute Capability: (8, 9)
